# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

# %% [markdown]
# # data pipeline

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/intents.json').read()
intents = json.loads(data_file)

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
pickle.dump(words,open('/content/words.pkl','wb'))
pickle.dump(classes,open('/content/classes.pkl','wb'))

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %% [markdown]
# # build model and training

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 10/10 [==============================] - 4s 3ms/step - loss: 2.2004 - accuracy: 0.1489
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1016 - accuracy: 0.1489
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0891 - accuracy: 0.2553
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8906 - accuracy: 0.3191
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8562 - accuracy: 0.4255
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7457 - accuracy: 0.5106
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5748 - accuracy: 0.5745
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5908 - accuracy: 0.5106
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2791 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2178 - accuracy: 0.6809
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0433 - accuracy: 0.6809
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9938 - accuracy: 0.7660
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8473 - accuracy: 0.7660
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8284 - accuracy: 0.7234
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7016 - accuracy: 0.8511
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7805 - accuracy: 0.7872
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6096 - accuracy: 0.8511
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6132 - accuracy: 0.8298
# Epoch 19/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5178 - accuracy: 0.8511
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5172 - accuracy: 0.8723
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5006 - accuracy: 0.8723
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4345 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2592 - accuracy: 0.9787
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3479 - accuracy: 0.8936
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2619 - accuracy: 0.9787
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2884 - accuracy: 0.9574
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3016 - accuracy: 0.9362
# Epoch 29/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2662 - accuracy: 0.9362
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.9149
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1365 - accuracy: 0.9787
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1742 - accuracy: 0.9574
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 1.0000
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2288 - accuracy: 0.8936
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2710 - accuracy: 0.8511
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2757 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1981 - accuracy: 0.9787
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 1.0000
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1544 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1603 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1640 - accuracy: 0.9362
# Epoch 42/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2329 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2073 - accuracy: 0.9362
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0751 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2148 - accuracy: 0.9362
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1577 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1569 - accuracy: 0.9362
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0852 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.9362
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1710 - accuracy: 0.9787
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.9149
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0816 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9787
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0809 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1318 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9787
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0611 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9574
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9787
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9574
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9787
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9787
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9787
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0633 - accuracy: 0.9574
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9787
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 0.9787
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0716 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9787
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9787
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0501 - accuracy: 0.9787
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0686 - accuracy: 0.9787
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9362
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9787
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 0.9787
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0455 - accuracy: 1.0000
# model created

# %% [markdown]
# # Implementing

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    print("bot:",res)

# %%
while True :
  msg = input("you:")
  chatbot_response(msg)
# Out:
# you:hi
# bot: Good to see you again
# you:how are you ?
# bot: Hi there, how can I help?
# you:bye
# bot: See you!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-671effcb2153> in <module>
#       1 while True :
# ----> 2   msg = input("you:")
#       3   chatbot_response(msg)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
